# %%
import numpy as np
import pandas as pd
from tqdm import tqdm

from soc.config import CATALOG_CSV, CATALOG_EMBEDDINGS, CATALOG_EMBEDDINGS_META
from soc.data.catalog import load_catalog
from soc.models.clip_encoder import CLIPEncoder

# %%
df = load_catalog(CATALOG_CSV)
df.head()
# Out:
#    item_id                          image_path category  color         style
# 0        1     data/catalog_images/shoe_01.jpg    shoes  white        casual
# 1        2     data/catalog_images/shoe_02.jpg    shoes  black        formal
# 2        3      data/catalog_images/bag_01.jpg      bag  brown        casual
# 3        4   data/catalog_images/jacket_01.jpg   jacket   blue  smart-casual
# 4        5  data/catalog_images/trouser_01.jpg  trouser  black        formal

# %%
encoder = CLIPEncoder()
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# open_clip_model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]

# %%
embeddings = []

for image_path in tqdm(df["image_path"]):
    emb = encoder.encode_image(image_path)
    embeddings.append(emb)

embeddings = np.vstack(embeddings)
embeddings.shape
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 embeddings = []
#       3 for image_path in tqdm(df["image_path"]):
# ----> 4     emb = encoder.encode_image(image_path)
#       5     embeddings.append(emb)
#       7 embeddings = np.vstack(embeddings)
#
# File ~/Farzad/Projects/SOC/.venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File ~/Farzad/Projects/SOC/src/soc/models/clip_encoder.py:33, in CLIPEncoder.encode_image(self, image_path)
#      31 @torch.no_grad()
#      32 def encode_image(self, image_path: str | Path) -> np.ndarray:
# ---> 33     image = load_image(image_path)
#      34     image_tensor = self.preprocess(image).unsqueeze(0).to(self.device)
#      35     features = self.model.encode_image(image_tensor)
#
# File ~/Farzad/Projects/SOC/src/soc/data/loaders.py:8, in load_image(image_path)
#       6 image_path = Path(image_path)
#       7 if not image_path.exists():
# ----> 8     raise FileNotFoundError(f"Image not found: {image_path}")
#       9 return Image.open(image_path).convert("RGB")
#
# FileNotFoundError: Image not found: data/catalog_images/shoe_01.jpg

# %%
np.save(CATALOG_EMBEDDINGS, embeddings)
df.to_csv(CATALOG_EMBEDDINGS_META, index=False)

print("Saved embeddings to:", CATALOG_EMBEDDINGS)
print("Saved metadata to:", CATALOG_EMBEDDINGS_META)
# Out:
# Saved embeddings to: /home/aaa79306/Farzad/Projects/SOC/outputs/embeddings/catalog_embeddings.npy
# Saved metadata to: /home/aaa79306/Farzad/Projects/SOC/outputs/embeddings/catalog_embeddings_meta.csv
