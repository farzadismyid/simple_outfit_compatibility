# %%
from soc.inference.recommend import recommend_from_image

# %%
query_image = "data/query_images/test_outfit.jpg"
results = recommend_from_image(
    query_image_path=query_image,
    top_k=5,
    target_category="shoes",
)
results
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#    item_id                       image_path category  color   style     score
# 0        2  data/catalog_images/shoe_02.jpg    shoes  black  formal  0.278299
# 1        1  data/catalog_images/shoe_01.jpg    shoes  white  casual  0.164507
